# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Owner\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sb 
import plotly.express as px 
import folium

# %%
path = "/Users/Owner/OneDrive/Programming/GitHub/BDAA Project SP25/Data Visualization/data/EEG_data.csv"

# %%
dataset = pd.read_csv(path)
display(dataset)
# Out:
#        video_id  subject_id      EEG.AF3       EEG.F7       EEG.F3  \
# 0             0           0  4210.641113  4179.102539  4287.948730
# 1             0           0  4201.025879  4188.717773  4280.128418
# 2             0           0  4203.205078  4182.820313  4282.820313
# 3             0           0  4186.538574  4168.717773  4266.794922
# 4             0           0  4232.436035  4216.922852  4306.922852
# ...         ...         ...          ...          ...          ...
# 68826        10           7  4353.846191  4349.487305  4317.563965
# 68827        10           7  4335.769043  4326.538574  4310.641113
# 68828        10           7  4321.666504  4313.205078  4310.000000
# 68829        10           7  4334.615234  4316.666504  4318.717773
# 68830        10           7  4328.589844  4308.589844  4310.384766
#
#            EEG.FC5       EEG.T7       EEG.P7       EEG.O1       EEG.O2  ...  \
# 0      4235.384766  4207.948730  4165.000000  4135.897461  4170.000000  ...
# 1      4236.922852  4209.615234  4152.436035  4130.128418  4149.487305  ...
# 2      4231.025879  4207.820313  4172.436035  4131.538574  4147.948730  ...
# 3      4229.230957  4202.179688  4155.384766  4128.333496  4151.666504  ...
# 4      4270.769043  4217.436035  4166.538574  4155.897461  4162.820313  ...
# ...            ...          ...          ...          ...          ...  ...
# 68826  4343.461426  4375.641113  4296.025879  4351.666504  4309.358887  ...
# 68827  4331.153809  4363.333496  4297.179688  4336.025879  4282.563965  ...
# 68828  4310.384766  4357.436035  4296.025879  4337.563965  4291.153809  ...
# 68829  4339.102539  4370.512695  4297.436035  4333.461426  4297.051270  ...
# 68830  4327.820313  4357.692383  4287.692383  4316.282227  4290.641113  ...
#
#        POW.F8.Alpha  POW.F8.BetaL  POW.F8.BetaH  POW.F8.Gamma  POW.AF4.Theta  \
# 0          1.583895      0.504567      0.471979      0.138717       1.801014
# 1          1.709560      0.606587      0.527616      0.155580       1.859177
# 2          1.873591      0.795834      0.565414      0.170816       2.027946
# 3          2.110017      1.021118      0.579656      0.180056       2.265952
# 4          2.462552      1.230984      0.573620      0.181081       2.461205
# ...             ...           ...           ...           ...            ...
# 68826      2.088463      0.925704      0.825126      0.576437       2.009375
# 68827      1.899325      0.833753      0.786224      0.600227       2.505607
# 68828      1.743110      0.789346      0.777936      0.631701       3.082165
# 68829      1.603054      0.781398      0.792152      0.661582       3.607407
# 68830      1.474767      0.820618      0.819320      0.675726       3.863732
#
#        POW.AF4.Alpha  POW.AF4.BetaL  POW.AF4.BetaH  POW.AF4.Gamma  \
# 0           1.504794       0.258570       0.435745       0.469483
# 1           1.379617       0.317579       0.468416       0.642560
# 2           1.283876       0.441925       0.494701       0.798197
# 3           1.306188       0.616881       0.506062       0.886495
# 4           1.522420       0.822598       0.498361       0.874455
# ...              ...            ...            ...            ...
# 68826       3.020382       2.115835       1.735570       1.125858
# 68827       2.680849       1.971062       1.468342       1.250918
# 68828       2.443027       1.868980       1.213362       1.373250
# 68829       2.341642       1.780673       0.982586       1.449505
# 68830       2.350165       1.698847       0.801526       1.448685
#
#        subject_understood
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 68826                   1
# 68827                   1
# 68828                   1
# 68829                   1
# 68830                   1
#
# [68831 rows x 87 columns]

# %%
# Count the occurrences of 0s and 1s
value_counts = dataset['subject_understood'].value_counts()

# Prepare the data for the pie chart
percent_comparison = value_counts / value_counts.sum() * 100  # Convert to percentages


plt.figure(figsize=(7, 7))
plt.pie(
    percent_comparison, 
    labels=["Not Understood (0)", "Understood (1)"],  # Custom labels
    autopct="%1.1f%%", 
    colors=["lightcoral", "lightsteelblue"]  # Custom colors
)
plt.title("Comparison of Videos Understood vs Not Understood")
plt.show()

# %%
dataset.describe().T
# Out:
#                       count         mean         std          min  \
# video_id            68831.0     5.624297    2.215993     0.000000
# subject_id          68831.0     3.710828    1.828410     0.000000
# EEG.AF3             68831.0  4276.496212  115.584631  1030.769287
# EEG.F7              68831.0  4257.994590  140.884855   805.384644
# EEG.F3              68831.0  4302.803482  113.720961  1320.769287
# ...                     ...          ...         ...          ...
# POW.AF4.Alpha       68831.0     8.133554   51.722390     0.077566
# POW.AF4.BetaL       68831.0     3.861532   35.243356     0.041230
# POW.AF4.BetaH       68831.0     1.520038   13.153730     0.056951
# POW.AF4.Gamma       68831.0     0.697575    3.937423     0.035907
# subject_understood  68831.0     0.789906    0.407378     0.000000
#
#                             25%          50%          75%          max
# video_id               5.000000     6.000000     6.000000    10.000000
# subject_id             3.000000     4.000000     4.000000     7.000000
# EEG.AF3             4258.461426  4287.307617  4311.153809  6238.077148
# EEG.F7              4236.410156  4266.538574  4296.153809  7599.615234
# EEG.F3              4283.205078  4305.897461  4327.692383  6291.794922
# ...                         ...          ...          ...          ...
# POW.AF4.Alpha          0.997642     1.679386     3.035433  3092.790283
# POW.AF4.BetaL          0.511406     0.833078     1.464920  3372.114746
# POW.AF4.BetaH          0.284404     0.472978     0.837565  1347.074341
# POW.AF4.Gamma          0.139540     0.262676     0.516598   331.578979
# subject_understood     1.000000     1.000000     1.000000     1.000000
#
# [87 rows x 8 columns]
